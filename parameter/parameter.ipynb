# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

# %%
# Erste Probemessung
Aloe_Data = "moist_measurement_1.csv"

t_Data = []
moist_Data = []

with open(Aloe_Data, 'r') as csvfile:
    # csv objekt erstellen
    csvreader = csv.reader(csvfile)
    
     # extracting field names through first row
    fields = next(csvreader)
 
 # Daten Zeile für Zeile einlesen
    for row in csvreader:
        t_Data.append(float(row[0])) 
        moist_Data.append(float(row[1]))
        
        
plt.plot(t_Data, moist_Data)
plt.show()

# %%
#Fördermengen pumpemessung

# Manuelle Dateneingabe aus dem Bild
u_in_v = [3, 3.2, 3.4, 3.6, 3.8, 4, 4.2, 4.4, 4.6]
t_in_s = [107, 96.5, 74.9, 66.7, 64, 63.2, 59.7, 54.4, 51.9]

# Erstellen von numpy-Arrays
u_in_v_array = np.array(u_in_v)
t_in_s_array = np.array(t_in_s)

plt.plot(u_in_v_array, t_in_s_array)
plt.show()
